# %% [markdown]
# <a href="https://colab.research.google.com/github/ikramulkayes/Datascience_Learning/blob/main/ml1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import tensorflow as tf

# %%
print(tf.version)
# Out:
# <module 'tensorflow._api.v2.version' from '/usr/local/lib/python3.7/dist-packages/tensorflow/_api/v2/version/__init__.py'>

# %%
k = tf.Variable([["Mac","Dj"],["Jack","Chan"]],tf.string)

# %%
tf.rank(k)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
k.shape
# Out:
# TensorShape([2, 2])
