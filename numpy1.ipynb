# %% [markdown]
# <a href="https://colab.research.google.com/github/ikramulkayes/Datascience_Learning/blob/main/numpy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = np.array([[1,53,31,523,3],[59,44,6464,7,444464646]])

# %%
print(a)
# Out:
# [[        1        53        31       523         3]
#  [       59        44      6464         7 444464646]]

# %%
print(a[1,2])
# Out:
# 6464

# %%
print(a[:,1:3])
# Out:
# [[  53   31]
#  [  44 6464]]
